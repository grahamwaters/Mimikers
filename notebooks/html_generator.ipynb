# %%
# !conda install -c conda-forge selenium -y
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.13) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/groupme
#
#   added / updated specs:
#     - selenium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     async_generator-1.10       |             py_0          18 KB  conda-forge
#     attrs-22.2.0               |     pyh71513ae_0          53 KB  conda-forge
#     brotlipy-0.7.0             |py39ha30fb19_1005         368 KB  conda-forge
#     cryptography-37.0.4        |   py39h9c2a9ce_0         1.2 MB  conda-forge
#     exceptiongroup-1.1.0       |     pyhd8ed1ab_0          18 KB  conda-forge
#     h11-0.14.0                 |     pyhd8ed1ab_0          47 KB  conda-forge
#     outcome-1.2.0              |     pyhd8ed1ab_0          12 KB  conda-forge
#     pyopenssl-22.0.0           |     pyhd8ed1ab_1         120 KB  conda-forge
#     selenium-4.7.2             |     pyhd8ed1ab_0         272 KB  conda-forge
#     sniffio-1.3.0              |     pyhd8ed1ab_0          14 KB  conda-forge
#     sortedcontainers-2.4.0     |     pyhd8ed1ab_0          26 KB  conda-forge
#     trio-0.22.0                |   py39h6e9494a_1         535 KB  conda-forge
#     trio-websocket-0.9.2       |     pyhd8ed1ab_0          25 KB  conda-forge
#     wsproto-1.2.0              |     pyhd8ed1ab_0          24 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   async_generator    conda-forge/noarch::async_generator-1.10-py_0
#   attrs              conda-forge/noarch::attrs-22.2.0-pyh71513ae_0
#   brotlipy           conda-forge/osx-64::brotlipy-0.7.0-py39ha30fb19_1005
#   cffi               pkgs/main/osx-64::cffi-1.15.1-py39hc55c11b_0
#   cryptography       conda-forge/osx-64::cryptography-37.0.4-py39h9c2a9ce_0
#   exceptiongroup     conda-forge/noarch::exceptiongroup-1.1.0-pyhd8ed1ab_0
#   h11                conda-forge/noarch::h11-0.14.0-pyhd8ed1ab_0
#   idna               conda-forge/noarch::idna-3.4-pyhd8ed1ab_0
#   outcome            conda-forge/noarch::outcome-1.2.0-pyhd8ed1ab_0
#   pycparser          conda-forge/noarch::pycparser-2.21-pyhd8ed1ab_0
#   pyopenssl          conda-forge/noarch::pyopenssl-22.0.0-pyhd8ed1ab_1
#   pysocks            conda-forge/noarch::pysocks-1.7.1-pyha2e5f31_6
#   selenium           conda-forge/noarch::selenium-4.7.2-pyhd8ed1ab_0
#   sniffio            conda-forge/noarch::sniffio-1.3.0-pyhd8ed1ab_0
#   sortedcontainers   conda-forge/noarch::sortedcontainers-2.4.0-pyhd8ed1ab_0
#   trio               conda-forge/osx-64::trio-0.22.0-py39h6e9494a_1
#   trio-websocket     conda-forge/noarch::trio-websocket-0.9.2-pyhd8ed1ab_0
#   typing_extensions  conda-forge/noarch::typing_extensions-4.4.0-pyha770c72_0
#   urllib3            conda-forge/noarch::urllib3-1.26.13-pyhd8ed1ab_0
#   wsproto            conda-forge/noarch::wsproto-1.2.0-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# cryptography-37.0.4  | 1.2 MB    |                                       |   0%
# exceptiongroup-1.1.0 | 18 KB     |                                       |   0%
#
# trio-websocket-0.9.2 | 25 KB     |                                       |   0%
#
#
# sortedcontainers-2.4 | 26 KB     |                                       |   0%
#
#
#
# wsproto-1.2.0        | 24 KB     |                                       |   0%
#
#
#
#
# pyopenssl-22.0.0     | 120 KB    |                                       |   0%
#
#
#
#
#
# outcome-1.2.0        | 12 KB     |                                       |   0%
#
#
#
#
#
#
# sniffio-1.3.0        | 14 KB     |                                       |   0%
#
#
#
#
#
#
#
# h11-0.14.0           | 47 KB     |                                       |   0%
#
#
#
#
#
#
#
#
# brotlipy-0.7.0       | 368 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# attrs-22.2.0         | 53 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# trio-0.22.0          | 535 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# selenium-4.7.2       | 272 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# async_generator-1.10 | 18 KB     |                                       |   0%
#
#
#
# wsproto-1.2.0        | 24 KB     | ########################5             |  66%
#
#
# sortedcontainers-2.4 | 26 KB     | #######################               |  62%
#
# cryptography-37.0.4  | 1.2 MB    | 4                                     |   1%
# cryptography-37.0.4  | 1.2 MB    | ###4                                  |   9%
#
#
#
#
#
# outcome-1.2.0        | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# h11-0.14.0           | 47 KB     | ############5                         |  34%
#
#
#
#
#
#
# sniffio-1.3.0        | 14 KB     | ##################################### | 100%
#
#
#
#
# pyopenssl-22.0.0     | 120 KB    | ####9                                 |  13%
# exceptiongroup-1.1.0 | 18 KB     | ##################################### | 100%
#
#
# sortedcontainers-2.4 | 26 KB     | ##################################### | 100%
#
#
# sortedcontainers-2.4 | 26 KB     | ##################################### | 100%
#
#
#
# wsproto-1.2.0        | 24 KB     | ##################################### | 100%
#
#
#
# wsproto-1.2.0        | 24 KB     | ##################################### | 100%
#
# trio-websocket-0.9.2 | 25 KB     | ##################################### | 100%
#
# trio-websocket-0.9.2 | 25 KB     | ##################################### | 100%
#
#
#
#
#
# cryptography-37.0.4  | 1.2 MB    | #################9                    |  49%
#
#
#
#
#
#
#
#
#
# attrs-22.2.0         | 53 KB     | ###########2                          |  30%
#
#
#
#
#
#
#
#
# brotlipy-0.7.0       | 368 KB    | #6                                    |   4%
#
#
#
#
#
#
# sniffio-1.3.0        | 14 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# selenium-4.7.2       | 272 KB    | ##1                                   |   6%
#
#
#
#
#
#
#
# h11-0.14.0           | 47 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# h11-0.14.0           | 47 KB     | ##################################### | 100%
#
#
#
#
# pyopenssl-22.0.0     | 120 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# trio-0.22.0          | 535 KB    | #1                                    |   3%
#
#
#
#
# cryptography-37.0.4  | 1.2 MB    | #################################     |  89%
#
#
#
#
#
#
#
#
# brotlipy-0.7.0       | 368 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# async_generator-1.10 | 18 KB     | #################################6    |  91%
#
#
#
#
#
#
#
#
#
# attrs-22.2.0         | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# attrs-22.2.0         | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# brotlipy-0.7.0       | 368 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# selenium-4.7.2       | 272 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# cryptography-37.0.4  | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# async_generator-1.10 | 18 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# trio-0.22.0          | 535 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
#!conda install -c conda-forge imgkit -y
# !pip install imgkit
# Out:
# Collecting imgkit
#   Downloading imgkit-1.2.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: six in /opt/anaconda3/envs/groupme/lib/python3.9/site-packages (from imgkit) (1.16.0)
# Installing collected packages: imgkit
# Successfully installed imgkit-1.2.2

# %%
import imgkit

def generate_card(title: str, description: str, points: str) -> None:
  # Create the HTML content for the card
  html = f"""
  <style>
    .card {{
      width: 550px;
      height: 850px;
      border: 1px solid black;
      border-radius: 5px;
      box-shadow: 2px 2px 5px rgba(0, 0, 0, 0.1);
      overflow: hidden;
    }}

    .card-title {{
      font-size: 20px;
      font-weight: bold;
      text-align: center;
      padding: 10px;
      background-color: lightblue;
      color: white;
    }}

    .card-description {{
      font-size: 16px;
      padding: 0 10px;
      line-height: 1.5;
    }}

    .card-points {{
      font-size: 14px;
      font-weight: bold;
      text-align: center;
      background-color: lightgray;
      color: black;
      padding: 10px;
      position: absolute;
      bottom: 0;
    }}
  </style>

  <div class="card">
    <div class="card-title">{title}</div>
    <div class="card-description">{description}</div>
    <div class="card-points">{points}</div>
  </div>
  """



imgkit.from_file('test.html', 'out.jpg')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[12], line 52
#       3 def generate_card(title: str, description: str, points: str) -> None:
#       4   # Create the HTML content for the card
#       5   html = f"""
#       6   <style>
#       7     .card {{
#    (...)
#      47   </div>
#      48   """
# ---> 52 imgkit.from_file('test.html', 'out.jpg')
#
# File /opt/anaconda3/envs/groupme/lib/python3.9/site-packages/imgkit/api.py:62, in from_file(filename, output_path, options, toc, cover, css, config, cover_first)
#      39 def from_file(
#      40     filename,
#      41     output_path,
#    (...)
#      47     cover_first=None,
#      48 ):
#      49     """
#      50     Convert HTML file/files to IMG file/files
#      51
#    (...)
#      60     :return: True when success
#      61     """
# ---> 62     rtn = IMGKit(
#      63         filename,
#      64         "file",
#      65         options=options,
#      66         toc=toc,
#      67         cover=cover,
#      68         css=css,
#      69         config=config,
#      70         cover_first=cover_first,
#      71     )
#      72     return rtn.to_img(output_path)
#
# File /opt/anaconda3/envs/groupme/lib/python3.9/site-packages/imgkit/imgkit.py:34, in IMGKit.__init__(self, url_or_file, source_type, options, config, **kwargs)
#      32 for param in params:
#      33     setattr(self, param, kwargs.get(param, None))
# ---> 34 self.source = Source(url_or_file, source_type)
#      35 self.config = Config() if not config else config
#      36 self.wkhtmltoimage = self.config.get_wkhtmltoimage()
#
# File /opt/anaconda3/envs/groupme/lib/python3.9/site-packages/imgkit/source.py:17, in Source.__init__(self, url_or_file, type_)
#      14 self.type = type_
#      16 if self.type == "file":
# ---> 17     self.checkFiles()
#
# File /opt/anaconda3/envs/groupme/lib/python3.9/site-packages/imgkit/source.py:46, in Source.checkFiles(self)
#      44 else:
#      45     if not hasattr(self.source, "read") and not os.path.exists(self.source):
# ---> 46         raise OSError("No such file: {}".format(self.source))
#
# OSError: No such file: test.html

# %% [markdown]
# ---

# %%
# !pip install html2image
# Out:
# Collecting html2image
#   Downloading html2image-2.0.1-py3-none-any.whl (17 kB)
# Installing collected packages: html2image
# Successfully installed html2image-2.0.1

# %%
html_text = f"""
<style>
  .card {{
    width: 550px;
    height: 850px;
    border: 1px solid black;
    border-radius: 5px;
    box-shadow: 2px 2px 5px rgba(0, 0, 0, 0.1);
    overflow: hidden;
  }}

  .card-title {{
    font-size: 20px;
    font-weight: bold;
    text-align: center;
    padding: 10px;
    background-color: lightblue;
    color: white;
  }}

  .card-description {{
    font-size: 16px;
    padding: 0 10px;
    line-height: 1.5;
  }}

  .card-points {{
    font-size: 14px;
    font-weight: bold;
    text-align: center;
    background-color: lightgray;
    color: black;
    padding: 10px;
    position: absolute;
    bottom: 0;
  }}
</style>

<div class="card">
  <div class="card-title">{title}</div>
  <div class="card-description">{description}</div>
  <div class="card-points">{points}</div>
</div>
"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 40
#       1 html_text = f"""
#       2 <style>
#       3   .card {{
#       4     width: 550px;
#       5     height: 850px;
#       6     border: 1px solid black;
#       7     border-radius: 5px;
#       8     box-shadow: 2px 2px 5px rgba(0, 0, 0, 0.1);
#       9     overflow: hidden;
#      10   }}
#      11
#      12   .card-title {{
#      13     font-size: 20px;
#      14     font-weight: bold;
#      15     text-align: center;
#      16     padding: 10px;
#      17     background-color: lightblue;
#      18     color: white;
#      19   }}
#      20
#      21   .card-description {{
#      22     font-size: 16px;
#      23     padding: 0 10px;
#      24     line-height: 1.5;
#      25   }}
#      26
#      27   .card-points {{
#      28     font-size: 14px;
#      29     font-weight: bold;
#      30     text-align: center;
#      31     background-color: lightgray;
#      32     color: black;
#      33     padding: 10px;
#      34     position: absolute;
#      35     bottom: 0;
#      36   }}
#      37 </style>
#      38
#      39 <div class="card">
# ---> 40   <div class="card-title">{title}</div>
#      41   <div class="card-description">{description}</div>
#      42   <div class="card-points">{points}</div>
#      43 </div>
#      44 """
#
# NameError: name 'title' is not defined

# %%
from html2image import Html2Image

def generate_card(title: str, description: str, points: str) -> None:
  # Create the HTML content for the card
  html = f"""
  <style>
    .card {
      width: 8.5cm;
      height: 5.5cm;
      border: 1px solid black;
      border-radius: 5px;
      box-shadow: 2px 2px 5px rgba(0, 0, 0, 0.1);
      overflow: hidden;
      background-color: white;
    }
    .card-title {{
      font-size: 20px;
      font-weight: bold;
      text-align: center;
      padding: 10px;
      background-color: lightblue;
      color: white;
    }}

    .card-description {{
      font-size: 16px;
      padding: 0 10px;
      line-height: 1.5;
    }}

    .card-points {{
      font-size: 14px;
      font-weight: bold;
      text-align: center;
      background-color: lightgray;
      color: black;
      padding: 10px;
      position: absolute;
      bottom: 0;
    }}
  </style>

  <div class="card">
    <div class="card-title">{title}</div>
    <div class="card-description">{description}</div>
    <div class="card-points">{points}</div>
  </div>
  """


  # Create an Html2Image object
  hti = Html2Image()

  # Generate a screenshot of the HTML content and save it to a file
  hti.screenshot(html_str=html, save_as='card.png')

# Example usage
generate_card('Card Title', 'Card Description', '10 Points')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 58
#      55   hti.screenshot(html_str=html, save_as='card.png')
#      57 # Example usage
# ---> 58 generate_card('Card Title', 'Card Description', '10 Points')
#
# Cell In[26], line 6, in generate_card(title, description, points)
#       3 def generate_card(title: str, description: str, points: str) -> None:
#       4   # Create the HTML content for the card
#       5   html = f"""
# ----> 6   <style>
#       7     .card {
#       8       width: 8.5cm;
#       9       height: 5.5cm;
#      10       border: 1px solid black;
#      11       border-radius: 5px;
#      12       box-shadow: 2px 2px 5px rgba(0, 0, 0, 0.1);
#      13       overflow: hidden;
#      14       background-color: white;
#      15     }
#      16     .card-title {{
#      17       font-size: 20px;
#      18       font-weight: bold;
#      19       text-align: center;
#      20       padding: 10px;
#      21       background-color: lightblue;
#      22       color: white;
#      23     }}
#      24
#      25     .card-description {{
#      26       font-size: 16px;
#      27       padding: 0 10px;
#      28       line-height: 1.5;
#      29     }}
#      30
#      31     .card-points {{
#      32       font-size: 14px;
#      33       font-weight: bold;
#      34       text-align: center;
#      35       background-color: lightgray;
#      36       color: black;
#      37       padding: 10px;
#      38       position: absolute;
#      39       bottom: 0;
#      40     }}
#      41   </style>
#      42
#      43   <div class="card">
#      44     <div class="card-title">{title}</div>
#      45     <div class="card-description">{description}</div>
#      46     <div class="card-points">{points}</div>
#      47   </div>
#      48   """
#      51   # Create an Html2Image object
#      52   hti = Html2Image()
#
# NameError: name 'width' is not defined
